# %% [markdown]
# ![TheBridge_logo_RGB_color.jpg](attachment:TheBridge_logo_RGB_color.jpg)

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 2:
# ## Tipos y conversión de tipos

# %% [markdown]
# Completa los siguiente ejercicios, la solución a los mismos se publicarán en el repo del curso a lo largo del sprint

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 1
#
# 1. Crea dos variables numericas: un `int` y un `float`
# 2. Comprueba sus tipos
# 3. Sumalas en otra nueva
# 4. ¿De qué tipo es la nueva variable?
# 5. Elimina las dos primeras variables creadas

# %%
entero = 4
real = 4.678
print (type(entero), type (real))
suma = entero + real
print ("La nueva variable es:", suma, "y su tipo es:", type(suma))
del entero
del real
# Out:
# <class 'int'> <class 'float'>
# La nueva variable es: 8.678 y su tipo es: <class 'float'>

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# radianes = grados*(pi/180)

# %%
import math
grados = float (input ("Introduce los grados a convertir:"))
radianes = grados*(math.pi/180)
print (grados, "grados son equivalentes a", radianes, "radianes")
# Out:
# Introduce los grados a convertir: 5
# 5.0 grados son equivalentes a 0.08726646259971647 radianes

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
base = float (input ("Introduce la base del paralelogramo en metros:"))
altura = float (input ("Introduce la altura del paralelogramo en metros:"))
area = base * altura
print ("El area del paralelogramo son", area, "m2")
# Out:
# Introduce la base del paralelogramo en metros: 4.5
# Introduce la altura del paralelogramo en metros: 3.1
# El area del paralelogramo son 13.950000000000001 m2

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 4
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`. En este caso debe ser capaz de admitir valores reales, con decimales, para base y altura en español. (PISTA: Recuerda que tendrás que hacer uso del método replace)

# %%
base = input ("Introduce la base del paralelogramo en metros:")
base_float = float (base.replace (",", "."))
altura = input ("Introduce la altura del paralelogramo en metros:")
altura_float = float (altura.replace (",", "."))
area = base_float * altura_float
print ("El area del paralelogramo son", area, "m2")
# Out:
# Introduce la base del paralelogramo en metros: 4,8
# Introduce la altura del paralelogramo en metros: 2,7
# El area del paralelogramo son 12.96 m2

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 5
# Complete el siguiente código para solicitar al usuario su nombre y su edad. Luego, calcule en qué año nació el usuario y muestre el resultado.

# %%
nombre = input ("¿Cuál es tu nombre? ")
edad = int (input("¿Cuál es tu edad? "))
año_actual = 2026  # Puedes cambiarlo según el año en curso
año_nacimiento = año_actual - edad

print(f"{nombre}, naciste en el año {año_nacimiento}.")
# Out:
# ¿Cuál es tu nombre?  Naia
# ¿Cuál es tu edad?  46
# Naia, naciste en el año 1980.
